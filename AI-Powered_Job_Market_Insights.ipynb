# %% [markdown]
# ## AI-Powered Job Market Insights
#
# ### - Overview:
#
# * The "AI-Powered Job Market Insights" dataset provides a synthetic but realistic snapshot of the modern job market, particularly focusing on the role of artificial intelligence (AI) and automation across various industries. This dataset includes 500 unique job listings, each characterized by different factors like industry, company size, AI adoption level, automation risk, required skills, and job growth projections. It is designed to be a valuable resource for researchers, data scientists, and policymakers exploring the impact of AI on employment, job market trends, and the future of work

# %% [markdown]
# ### Loading and Understanding the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 

warnings.simplefilter(action='ignore', category=FutureWarning)

df = pd.read_csv(r"F:\Data Science (Analytics)\Pyhton\Pandas\ai_job_market_insights.csv")
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills  Salary_USD  \
# 0              Medium            High        UX/UI Design   111392.17
# 1              Medium            High           Marketing    93792.56
# 2              Medium            High        UX/UI Design   107170.26
# 3                 Low            High  Project Management    93027.95
# 4                 Low             Low          JavaScript    87752.92
# ..                ...             ...                 ...         ...
# 495               Low          Medium    Machine Learning   105821.39
# 496               Low            High        UX/UI Design   119794.99
# 497              High             Low        UX/UI Design    79644.93
# 498              High             Low              Python    77642.15
# 499            Medium            High  Project Management    68764.38
#
#     Remote_Friendly Job_Growth_Projection
# 0               Yes                Growth
# 1                No               Decline
# 2               Yes                Growth
# 3                No                Growth
# 4               Yes               Decline
# ..              ...                   ...
# 495             Yes                Stable
# 496              No               Decline
# 497             Yes                Stable
# 498             Yes                Stable
# 499             Yes               Decline
#
# [500 rows x 10 columns]

# %%
print("DataSet Info: \n")
df.info()

print("\n Columns of the Data Set: \n")
df.columns.to_list()
# Out:
# DataSet Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_Title              500 non-null    object
#  1   Industry               500 non-null    object
#  2   Company_Size           500 non-null    object
#  3   Location               500 non-null    object
#  4   AI_Adoption_Level      500 non-null    object
#  5   Automation_Risk        500 non-null    object
#  6   Required_Skills        500 non-null    object
#  7   Salary_USD             500 non-null    float64
#  8   Remote_Friendly        500 non-null    object
#  9   Job_Growth_Projection  500 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 39.2+ KB
#
#  Columns of the Data Set:
# ['Job_Title',
#  'Industry',
#  'Company_Size',
#  'Location',
#  'AI_Adoption_Level',
#  'Automation_Risk',
#  'Required_Skills',
#  'Salary_USD',
#  'Remote_Friendly',
#  'Job_Growth_Projection']

# %%
print("Preview of the top Dataset: \n")
df.head()
# Out:
# Preview of the top Dataset:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills  Salary_USD  \
# 0            Medium            High        UX/UI Design   111392.17
# 1            Medium            High           Marketing    93792.56
# 2            Medium            High        UX/UI Design   107170.26
# 3               Low            High  Project Management    93027.95
# 4               Low             Low          JavaScript    87752.92
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# 2             Yes                Growth
# 3              No                Growth
# 4             Yes               Decline

# %%
print("\n Preview of the Bottom Dataset: \n")
df.tail()
# Out:
#  Preview of the Bottom Dataset:
#                  Job_Title            Industry Company_Size Location  \
# 495         Data Scientist  Telecommunications       Medium   Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small   London
# 497  Cybersecurity Analyst              Energy        Large    Dubai
# 498     Operations Manager          Healthcare        Large    Paris
# 499             HR Manager       Entertainment       Medium   Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills  Salary_USD  \
# 495               Low          Medium    Machine Learning   105821.39
# 496               Low            High        UX/UI Design   119794.99
# 497              High             Low        UX/UI Design    79644.93
# 498              High             Low              Python    77642.15
# 499            Medium            High  Project Management    68764.38
#
#     Remote_Friendly Job_Growth_Projection
# 495             Yes                Stable
# 496              No               Decline
# 497             Yes                Stable
# 498             Yes                Stable
# 499             Yes               Decline

# %%
print("\n Statstics Summary: \n")
df.describe(include="all")
# Out:
#  Statstics Summary:
#              Job_Title       Industry Company_Size       Location  \
# count              500            500          500            500
# unique              10             10            3             10
# top     Data Scientist  Manufacturing        Small  San Francisco
# freq                62             58          171             62
# mean               NaN            NaN          NaN            NaN
# std                NaN            NaN          NaN            NaN
# min                NaN            NaN          NaN            NaN
# 25%                NaN            NaN          NaN            NaN
# 50%                NaN            NaN          NaN            NaN
# 75%                NaN            NaN          NaN            NaN
# max                NaN            NaN          NaN            NaN
#
#        AI_Adoption_Level Automation_Risk Required_Skills  Salary_USD  \
# count                500             500             500      500.00
# unique                 3               3              10         NaN
# top               Medium          Medium          Python         NaN
# freq                 179             173              60         NaN
# mean                 NaN             NaN             NaN    91222.39
# std                  NaN             NaN             NaN    20504.29
# min                  NaN             NaN             NaN    31969.53
# 25%                  NaN             NaN             NaN    78511.51
# 50%                  NaN             NaN             NaN    91998.20
# 75%                  NaN             NaN             NaN   103971.28
# max                  NaN             NaN             NaN   155209.82
#
#        Remote_Friendly Job_Growth_Projection
# count              500                   500
# unique               2                     3
# top                Yes                Growth
# freq               251                   169
# mean               NaN                   NaN
# std                NaN                   NaN
# min                NaN                   NaN
# 25%                NaN                   NaN
# 50%                NaN                   NaN
# 75%                NaN                   NaN
# max                NaN                   NaN

# %%
print("\n Categorical Data Columns : \n")
df.select_dtypes(include='object').columns.to_list()
# Out:
#  Categorical Data Columns :
# ['Job_Title',
#  'Industry',
#  'Company_Size',
#  'Location',
#  'AI_Adoption_Level',
#  'Automation_Risk',
#  'Required_Skills',
#  'Remote_Friendly',
#  'Job_Growth_Projection']

# %%
print("\n Numerical Data Columns : \n")
df.select_dtypes(include='number').columns.to_list()
# Out:
#  Numerical Data Columns :
# ['Salary_USD']

# %% [markdown]
# #### Cleaning Data

# %%
# Checking for the NUll Values

print("\n Missing Values : \n")
df.isna().sum()
# Out:
#  Missing Values :
# Job_Title                0
# Industry                 0
# Company_Size             0
# Location                 0
# AI_Adoption_Level        0
# Automation_Risk          0
# Required_Skills          0
# Salary_USD               0
# Remote_Friendly          0
# Job_Growth_Projection    0
# dtype: int64

# %%
# Checking for Duplicates

if df.duplicated().sum() > 0:
    df.drop_duplicates(inplace=True)
    print(f"Duplicates: {df.duplicated().sum()}\n Duplicates Droped \n data frame shape is: {df.shape}")
else:
    print(f"Duplicates: {df.duplicated().sum()}\n No changes done. \n data frame shape is: {df.shape}")
# Out:
# Duplicates: 0
#  No changes done.
#  data frame shape is: (500, 10)

# %% [markdown]
# #### Analyzing The Data

# %%
# getting unique values for categorical columns

print("\n Unique values for the categorical columns: \n")

for cate_col in df.select_dtypes(include='object').columns:
    print(f"{cate_col} : {df[cate_col].nunique()} Unique Values")
# Out:
#  Unique values for the categorical columns:
#
# Job_Title : 10 Unique Values
# Industry : 10 Unique Values
# Company_Size : 3 Unique Values
# Location : 10 Unique Values
# AI_Adoption_Level : 3 Unique Values
# Automation_Risk : 3 Unique Values
# Required_Skills : 10 Unique Values
# Remote_Friendly : 2 Unique Values
# Job_Growth_Projection : 3 Unique Values

# %%
# getting unique values for Numerical columns

print("\n Unique values for the Numerical columns: \n")

for Num_col in df.select_dtypes(include='number').columns:
    print(f"{Num_col} : {df[Num_col].nunique()} Unique Values")
# Out:
#  Unique values for the Numerical columns:
#
# Salary_USD : 500 Unique Values

# %%
Count_of_job_title = df.groupby('Industry')['Job_Title'].nunique()
Count_of_job_title
# Out:
# Industry
# Education             10
# Energy                10
# Entertainment         10
# Finance               10
# Healthcare            10
# Manufacturing         10
# Retail                10
# Technology            10
# Telecommunications    10
# Transportation        10
# Name: Job_Title, dtype: int64

# %%
# Salary Distribution by Industry

plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='Industry', y='Salary_USD', palette='muted', hue='AI_Adoption_Level')
plt.xticks(rotation=45)
plt.title("Salary Distribution by Industry with AI_Adoption_Level")
plt.xlabel("Industry")
plt.ylabel("Salary_USD")
plt.show()

# %%
# Salary Distribution by Job_Title

plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='Job_Title', y='Salary_USD', hue='AI_Adoption_Level', palette='coolwarm')
plt.title("Salary Distribution by Job_title with AI_Adoption_Level")
plt.xlabel("Job_Title")
plt.ylabel("Salary")
plt.show()

# %%
# Salary Distribution by AI Adoption Levels

plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='AI_Adoption_Level', y='Salary_USD', palette='Set2')
plt.title("Salary Distribution by the AI_Adoption_Level with Company size")
plt.show()

# %%
# Remote friendly Jobs by salary

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Remote_Friendly', y='Salary_USD')
plt.title("Remote-Friendly Jobs by salary")
plt.show()

# %%
# Distribution of Remote-Friendly

clr = plt.get_cmap('Pastel1_r').colors

df['Remote_Friendly'].value_counts().plot(kind='pie', startangle = 20, autopct = '%1.1f%%', figsize=(20, 8), 
                                          title='Distribution of Remote_Friendly', explode = (0.08, 0), shadow = True, colors = clr)
plt.show()

# %%
#  Job Growth Projection by Location

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Location', hue='Job_Growth_Projection', palette='viridis')
plt.xticks(rotation=45)
plt.title("Job Growth Projection by Location")
plt.ylabel("No of Jobs")
plt.show()

# %% [markdown]
# #### Correlations

# %%
# Correlations between Salary, AI-Adoption-Level and Automation-Risk

# Encoding Categorical values to numbers for correlate.

encoded_data = df.copy()
encoded_data['AI_Adoption_Level'] = encoded_data['AI_Adoption_Level'].map({'Low': 1, 'Medium': 2, 'High': 3})
encoded_data['Automation_Risk'] = encoded_data['Automation_Risk'].map({'Low': 1, 'Medium': 2, 'High': 3})

corrrelation_Matrix = encoded_data[['Salary_USD', 'AI_Adoption_Level', 'Automation_Risk']].corr() # Correlating
# corrrelation_Matrix

# Heatmap visual for better Understanding

plt.figure(figsize=(12, 6))
sns.heatmap(corrrelation_Matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation between Salary_USD, AI_Adoption_Level and Automation_Risk")
plt.tight_layout()
plt.show()

# %%
# Skills Demanded in High-Growth Jobs

high_growth_jobs = df[df['Job_Growth_Projection'] == 'Growth'] # filtering the growth jobs

skills_demand = high_growth_jobs['Required_Skills'].value_counts()
skills_demand

# visualizing the required skills for high-growth jobs

plt.figure(figsize=(12, 6))
sns.barplot(x=skills_demand.values, y= skills_demand.index, hue= skills_demand.index, palette='mako')
plt.title("Skills Demanded in High growth Jobs")
plt.xlabel("No of Jobs")
plt.show()

# %%
# Skill Requirements

all_skills = [skills for subskill in df['Required_Skills'] for skills in subskill]
skill_count = pd.Series(all_skills).value_counts()
top_skill = skill_count.head(10)

# skills by Job_Title

grp_df = df.groupby('Job_Title')
count_by_role = grp_df['Required_Skills'].apply(lambda x : pd.Series(x).value_counts())

count_by_role
# Out:
# Job_Title
# AI Researcher  JavaScript          9
#                Python              9
#                Sales               7
#                Cybersecurity       5
#                UX/UI Design        4
#                                   ..
# UX Designer    JavaScript          4
#                UX/UI Design        3
#                Communication       3
#                Sales               3
#                Machine Learning    2
# Name: Required_Skills, Length: 100, dtype: int64

# %%
df.groupby(['Required_Skills', 'Job_Title']).size().unstack()
# Out:
# Job_Title           AI Researcher  Cybersecurity Analyst  Data Scientist  \
# Required_Skills
# Communication                   4                      3               2
# Cybersecurity                   5                     10               9
# Data Analysis                   4                      3               7
# JavaScript                      9                      4               3
# Machine Learning                2                      7               6
# Marketing                       4                      5               5
# Project Management              3                      5               7
# Python                          9                      5               9
# Sales                           7                      4               8
# UX/UI Design                    4                      9               6
#
# Job_Title           HR Manager  Marketing Specialist  Operations Manager  \
# Required_Skills
# Communication                4                     6                   5
# Cybersecurity                6                     3                   5
# Data Analysis                7                     4                   3
# JavaScript                   5                     4                   5
# Machine Learning            10                     1                   4
# Marketing                    5                     8                   1
# Project Management           6                     2                   5
# Python                       3                    10                   5
# Sales                        6                     6                   5
# UX/UI Design                 5                     4                   6
#
# Job_Title           Product Manager  Sales Manager  Software Engineer  \
# Required_Skills
# Communication                     2              1                  4
# Cybersecurity                     2              8                  2
# Data Analysis                     2              9                  5
# JavaScript                        5              2                  3
# Machine Learning                  7              7                  6
# Marketing                         3              2                  5
# Project Management                6              7                  5
# Python                            5              6                  3
# Sales                             2              4                  4
# UX/UI Design                      5              3                  4
#
# Job_Title           UX Designer
# Required_Skills
# Communication                 3
# Cybersecurity                 8
# Data Analysis                 5
# JavaScript                    4
# Machine Learning              2
# Marketing                     7
# Project Management           14
# Python                        5
# Sales                         3
# UX/UI Design                  3

# %%
# Count of Job Titles

plt.figure(figsize=(12, 6))
sns.countplot(data= df, y='Job_Title', order=df['Job_Title'].value_counts().index, palette='mako')
plt.show()

# %%
# Job Counts by Location 

df.groupby('Job_Title')['Location'].value_counts().unstack()
# Out:
# Location               Berlin  Dubai  London  New York  Paris  San Francisco  \
# Job_Title
# AI Researcher               2      3       3         6      2             10
# Cybersecurity Analyst       7      9       8         6      4              4
# Data Scientist              7      6       5         8      4              6
# HR Manager                  5      4       8         6      8              7
# Marketing Specialist        6      5       4         2      6              9
# Operations Manager          7      6       5         4      2              7
# Product Manager             4      2       3         2      4              6
# Sales Manager               5      3       6         3      5              5
# Software Engineer           2      5       3         5      4              3
# UX Designer                 3      8       1         7      7              5
#
# Location               Singapore  Sydney  Tokyo  Toronto
# Job_Title
# AI Researcher                  8       5      5        7
# Cybersecurity Analyst          3       7      3        4
# Data Scientist                 5       8      8        5
# HR Manager                     6       3      5        5
# Marketing Specialist           6       3      6        1
# Operations Manager             4       4      4        1
# Product Manager                3       5      5        5
# Sales Manager                  7       5      3        7
# Software Engineer              6       6      5        2
# UX Designer                    6       6      7        4

# %%
# Automation-Risk 

df.groupby(['Automation_Risk', 'Job_Title']).size().unstack()
# Out:
# Job_Title        AI Researcher  Cybersecurity Analyst  Data Scientist  \
# Automation_Risk
# High                        20                     23              17
# Low                         15                     21              25
# Medium                      16                     11              20
#
# Job_Title        HR Manager  Marketing Specialist  Operations Manager  \
# Automation_Risk
# High                     15                    17                  10
# Low                      16                    10                  18
# Medium                   26                    21                  16
#
# Job_Title        Product Manager  Sales Manager  Software Engineer  \
# Automation_Risk
# High                          16             20                 15
# Low                           12             18                 13
# Medium                        11             11                 13
#
# Job_Title        UX Designer
# Automation_Risk
# High                      16
# Low                       10
# Medium                    28

# %%
df.groupby(['Automation_Risk', 'Industry']).size().unstack()
# Out:
# Industry         Education  Energy  Entertainment  Finance  Healthcare  \
# Automation_Risk
# High                    22      17             18       17          11
# Low                     16      18             17       16          14
# Medium                  19      14             12       20          17
#
# Industry         Manufacturing  Retail  Technology  Telecommunications  \
# Automation_Risk
# High                        19      11          17                  18
# Low                         16      16          17                  17
# Medium                      23      19          22                  18
#
# Industry         Transportation
# Automation_Risk
# High                         19
# Low                          11
# Medium                        9

# %%
df.groupby(['Automation_Risk', 'Location']).size().unstack()
# Out:
# Location         Berlin  Dubai  London  New York  Paris  San Francisco  \
# Automation_Risk
# High                 12     14      20        17     12             24
# Low                  16     20      17        10     16             17
# Medium               20     17       9        22     18             21
#
# Location         Singapore  Sydney  Tokyo  Toronto
# Automation_Risk
# High                    23      17     15       15
# Low                     12      20     15       15
# Medium                  19      15     21       11
